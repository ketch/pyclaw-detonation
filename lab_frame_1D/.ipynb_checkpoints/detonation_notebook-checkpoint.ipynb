# %%
import numpy as np
import matplotlib.pylab as plt
from clawpack import pyclaw
from clawpack import riemann
import reactive_euler_1D_roe_efix as rp_solver
import steadyState as steadyState

# %%
# %pylab inline
gamma = 1.2
gamma1 = gamma - 1
qheat = 50
Ea = 26
T_ign = 4
mx = 200
xmax=25
tfinal = 100
dtplot = 1
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['plt']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
def step_reaction(solver, state, dt):
    global k
    q = state.q
    q[0,:] = q[0,:]
    q[1,:] = q[1,:]
    q[2,:] = q[2,:]
    q[3,:] = q[3,:] + dt*omega(q, k)

def step_reaction_dq(solver, state, dt):
    global k
    q = state.q
    dq = np.empty(q.shape)
    dq[3,:] = dt*omega(q, k)
    return dq
    
def omega(q, k):
    """ Reaction rate function
    """
    import numpy as np
    pressure = gamma1*(q[2,:]-0.5*q[1,:]**2/q[0,:] -
                        qheat*q[3,:])
    T = pressure / q[0,:]
    return -k*(q[3,:])*np.exp(-Ea/T)*(T>T_ign)

# %%
solver = pyclaw.ClawSolver1D(rp_solver)
solver.step_source = step_reaction
solver.limiters = 1
#solver = pyclaw.SharpClawSolver1D(reactive_euler_efix_roe_1D)
#solver.dq_src = step_reaction_dq
#solver.weno_order = 5
solver.bc_lower[0]=pyclaw.BC.extrap
solver.bc_upper[0]=pyclaw.BC.extrap
solver.num_eqn = 4
solver.num_waves = 4

# %%
 # Initialize domain
x = pyclaw.Dimension('x',0.0,xmax,mx)
domain = pyclaw.Domain([x])
state = pyclaw.State(domain,solver.num_eqn)

x =state.grid.x.centers
xs = xmax-5
xdet = x[x<xs]

rhol, Ul, pl, laml, D, k = steadyState.steadyState(qheat, Ea, gamma, xdet)
ul = Ul + D
Yl = 1-laml
print("k="+str(k))

rhor = 1.*np.ones(np.shape(x[x>=xs]))
ur = 0.0*np.ones(np.shape(x[x>=xs]))
pr = 1*np.ones(np.shape(x[x>=xs]))
Yr = 1.*np.ones(np.shape(x[x>=xs]))

rho = np.append(rhol, rhor)
u = np.append(ul, ur)
p = np.append(pl, pr)
Y = np.append(Yl, Yr)
# Out:
# k=42.1483488849

# %%
state.q[0,:] = rho
state.q[1,:] = rho*u
state.q[2,:] = p/gamma1 + rho*u**2/2 + qheat*rho*Y
state.q[3,:] = rho*Y   

state.problem_data['gamma']= gamma
state.problem_data['gamma1']= gamma1
state.problem_data['qheat']= qheat
state.problem_data['Ea'] = Ea
state.problem_data['T_ign'] = T_ign
state.problem_data['xfspeed'] = 1.*D

# %%
claw = pyclaw.Controller()
claw.tfinal = tfinal
claw.keep_copy = True       # Keep solution data in memory for plotting
claw.num_output_times = np.ceil(claw.tfinal / dtplot)  # Write 50 output frames
claw.solution = pyclaw.Solution(state,domain)
claw.solver = solver

# %%
claw.out_times
# Out:
# array([ 0.        ,  0.11111111,  0.22222222,  0.33333333,  0.44444444,
#         0.55555556,  0.66666667,  0.77777778,  0.88888889,  1.        ])

# %% [markdown]
# Finally, let's run the simulation.

# %%
status = claw.run();
# Out:
# 2015-08-12 17:02:50,413 INFO CLAW: Solution 0 computed for time t=0.000000
# 2015-08-12 17:02:50,472 INFO CLAW: Solution 1 computed for time t=1.000000
# 2015-08-12 17:02:50,543 INFO CLAW: Solution 2 computed for time t=2.000000
# 2015-08-12 17:02:50,640 INFO CLAW: Solution 3 computed for time t=3.000000
# 2015-08-12 17:02:50,731 INFO CLAW: Solution 4 computed for time t=4.000000
# 2015-08-12 17:02:50,827 INFO CLAW: Solution 5 computed for time t=5.000000
# 2015-08-12 17:02:50,927 INFO CLAW: Solution 6 computed for time t=6.000000
# 2015-08-12 17:02:51,030 INFO CLAW: Solution 7 computed for time t=7.000000
# 2015-08-12 17:02:51,137 INFO CLAW: Solution 8 computed for time t=8.000000
# 2015-08-12 17:02:51,246 INFO CLAW: Solution 9 computed for time t=9.000000
# 2015-08-12 17:02:51,357 INFO CLAW: Solution 10 computed for time t=10.000000
# 2015-08-12 17:02:51,471 INFO CLAW: Solution 11 computed for time t=11.000000
# 2015-08-12 17:02:51,584 INFO CLAW: Solution 12 computed for time t=12.000000
# 2015-08-12 17:02:51,692 INFO CLAW: Solution 13 computed for time t=13.000000
# 2015-08-12 17:02:51,794 INFO CLAW: Solution 14 computed for time t=14.000000
# 2015-08-12 17:02:51,888 INFO CLAW: Solution 15 computed for time t=15.000000
# 2015-08-12 17:02:51,975 INFO CLAW: Solution 16 computed for time t=16.000000
# 2015-08-12 17:02:52,063 INFO CLAW: Solution 17 computed for time t=17.000000
# 2015-08-12 17:02:52,151 INFO CLAW: Solution 18 computed for time t=18.000000
# 2015-08-12 17:02:52,239 INFO CLAW: Solution 19 computed for time t=19.000000
# 2015-08-12 17:02:52,326 INFO CLAW: Solution 20 computed for time t=20.000000
# 2015-08-12 17:02:52,414 INFO CLAW: Solution 21 computed for time t=21.000000
# 2015-08-12 17:02:52,501 INFO CLAW: Solution 22 computed for time t=22.000000
# 2015-08-12 17:02:52,588 INFO CLAW: Solution 23 computed for time t=23.000000
# 2015-08-12 17:02:52,675 INFO CLAW: Solution 24 computed for time t=24.000000
# 2015-08-12 17:02:52,762 INFO CLAW: Solution 25 computed for time t=25.000000
# 2015-08-12 17:02:52,849 INFO CLAW: Solution 26 computed for time t=26.000000
# 2015-08-12 17:02:52,937 INFO CLAW: Solution 27 computed for time t=27.000000
# 2015-08-12 17:02:53,024 INFO CLAW: Solution 28 computed for time t=28.000000
# 2015-08-12 17:02:53,111 INFO CLAW: Solution 29 computed for time t=29.000000
# 2015-08-12 17:02:53,198 INFO CLAW: Solution 30 computed for time t=30.000000
# 2015-08-12 17:02:53,286 INFO CLAW: Solution 31 computed for time t=31.000000
# 2015-08-12 17:02:53,374 INFO CLAW: Solution 32 computed for time t=32.000000
# 2015-08-12 17:02:53,461 INFO CLAW: Solution 33 computed for time t=33.000000
# 2015-08-12 17:02:53,549 INFO CLAW: Solution 34 computed for time t=34.000000
# 2015-08-12 17:02:53,636 INFO CLAW: Solution 35 computed for time t=35.000000
# 2015-08-12 17:02:53,716 INFO CLAW: Solution 36 computed for time t=36.000000
# 2015-08-12 17:02:53,793 INFO CLAW: Solution 37 computed for time t=37.000000
# 2015-08-12 17:02:53,870 INFO CLAW: Solution 38 computed for time t=38.000000
# 2015-08-12 17:02:53,946 INFO CLAW: Solution 39 computed for time t=39.000000
# 2015-08-12 17:02:54,023 INFO CLAW: Solution 40 computed for time t=40.000000
# 2015-08-12 17:02:54,100 INFO CLAW: Solution 41 computed for time t=41.000000
# 2015-08-12 17:02:54,176 INFO CLAW: Solution 42 computed for time t=42.000000
# 2015-08-12 17:02:54,253 INFO CLAW: Solution 43 computed for time t=43.000000
# 2015-08-12 17:02:54,330 INFO CLAW: Solution 44 computed for time t=44.000000
# 2015-08-12 17:02:54,406 INFO CLAW: Solution 45 computed for time t=45.000000
# 2015-08-12 17:02:54,483 INFO CLAW: Solution 46 computed for time t=46.000000
# 2015-08-12 17:02:54,559 INFO CLAW: Solution 47 computed for time t=47.000000
# 2015-08-12 17:02:54,636 INFO CLAW: Solution 48 computed for time t=48.000000
# 2015-08-12 17:02:54,713 INFO CLAW: Solution 49 computed for time t=49.000000
# 2015-08-12 17:02:54,790 INFO CLAW: Solution 50 computed for time t=50.000000
# 2015-08-12 17:02:54,866 INFO CLAW: Solution 51 computed for time t=51.000000
# 2015-08-12 17:02:54,942 INFO CLAW: Solution 52 computed for time t=52.000000
# 2015-08-12 17:02:55,019 INFO CLAW: Solution 53 computed for time t=53.000000
# 2015-08-12 17:02:55,098 INFO CLAW: Solution 54 computed for time t=54.000000
# 2015-08-12 17:02:55,175 INFO CLAW: Solution 55 computed for time t=55.000000
# 2015-08-12 17:02:55,253 INFO CLAW: Solution 56 computed for time t=56.000000
# 2015-08-12 17:02:55,330 INFO CLAW: Solution 57 computed for time t=57.000000
# 2015-08-12 17:02:55,407 INFO CLAW: Solution 58 computed for time t=58.000000
# 2015-08-12 17:02:55,484 INFO CLAW: Solution 59 computed for time t=59.000000
# 2015-08-12 17:02:55,563 INFO CLAW: Solution 60 computed for time t=60.000000
# 2015-08-12 17:02:55,640 INFO CLAW: Solution 61 computed for time t=61.000000
# 2015-08-12 17:02:55,717 INFO CLAW: Solution 62 computed for time t=62.000000
# 2015-08-12 17:02:55,794 INFO CLAW: Solution 63 computed for time t=63.000000
# 2015-08-12 17:02:55,870 INFO CLAW: Solution 64 computed for time t=64.000000
# 2015-08-12 17:02:55,947 INFO CLAW: Solution 65 computed for time t=65.000000
# 2015-08-12 17:02:56,024 INFO CLAW: Solution 66 computed for time t=66.000000
# 2015-08-12 17:02:56,107 INFO CLAW: Solution 67 computed for time t=67.000000
# 2015-08-12 17:02:56,195 INFO CLAW: Solution 68 computed for time t=68.000000
# 2015-08-12 17:02:56,283 INFO CLAW: Solution 69 computed for time t=69.000000
# 2015-08-12 17:02:56,370 INFO CLAW: Solution 70 computed for time t=70.000000
# 2015-08-12 17:02:56,458 INFO CLAW: Solution 71 computed for time t=71.000000
# 2015-08-12 17:02:56,546 INFO CLAW: Solution 72 computed for time t=72.000000
# 2015-08-12 17:02:56,634 INFO CLAW: Solution 73 computed for time t=73.000000
# 2015-08-12 17:02:56,722 INFO CLAW: Solution 74 computed for time t=74.000000
# 2015-08-12 17:02:56,809 INFO CLAW: Solution 75 computed for time t=75.000000
# 2015-08-12 17:02:56,897 INFO CLAW: Solution 76 computed for time t=76.000000
# 2015-08-12 17:02:56,984 INFO CLAW: Solution 77 computed for time t=77.000000
# 2015-08-12 17:02:57,072 INFO CLAW: Solution 78 computed for time t=78.000000
# 2015-08-12 17:02:57,160 INFO CLAW: Solution 79 computed for time t=79.000000
# 2015-08-12 17:02:57,248 INFO CLAW: Solution 80 computed for time t=80.000000
# 2015-08-12 17:02:57,336 INFO CLAW: Solution 81 computed for time t=81.000000
# 2015-08-12 17:02:57,424 INFO CLAW: Solution 82 computed for time t=82.000000
# 2015-08-12 17:02:57,512 INFO CLAW: Solution 83 computed for time t=83.000000
# 2015-08-12 17:02:57,600 INFO CLAW: Solution 84 computed for time t=84.000000
# 2015-08-12 17:02:57,688 INFO CLAW: Solution 85 computed for time t=85.000000
# 2015-08-12 17:02:57,776 INFO CLAW: Solution 86 computed for time t=86.000000
# 2015-08-12 17:02:57,863 INFO CLAW: Solution 87 computed for time t=87.000000
# 2015-08-12 17:02:57,951 INFO CLAW: Solution 88 computed for time t=88.000000
# 2015-08-12 17:02:58,039 INFO CLAW: Solution 89 computed for time t=89.000000
# 2015-08-12 17:02:58,127 INFO CLAW: Solution 90 computed for time t=90.000000
# 2015-08-12 17:02:58,214 INFO CLAW: Solution 91 computed for time t=91.000000
# 2015-08-12 17:02:58,302 INFO CLAW: Solution 92 computed for time t=92.000000
# 2015-08-12 17:02:58,389 INFO CLAW: Solution 93 computed for time t=93.000000
# 2015-08-12 17:02:58,477 INFO CLAW: Solution 94 computed for time t=94.000000
# 2015-08-12 17:02:58,564 INFO CLAW: Solution 95 computed for time t=95.000000
# 2015-08-12 17:02:58,651 INFO CLAW: Solution 96 computed for time t=96.000000
# 2015-08-12 17:02:58,739 INFO CLAW: Solution 97 computed for time t=97.000000
# 2015-08-12 17:02:58,826 INFO CLAW: Solution 98 computed for time t=98.000000
# 2015-08-12 17:02:58,913 INFO CLAW: Solution 99 computed for time t=99.000000
# 2015-08-12 17:02:59,001 INFO CLAW: Solution 100 computed for time t=100.000000

# %% [markdown]
# ## Plotting
# Now we'll plot the results, which are contained in `claw.frames[:]`.  It's simple to plot a single frame with matplotlib:

# %%
def pressure(current_data):
    q = current_data.q
    rho = q[0,:]
    u   = q[1,:]/rho
    press = gamma1 *  (q[2,:] - 0.5*rho*(u**2) - qheat*q[3,:])
    return press

# %%
frameno=0
density = claw.frames[frameno].q[0,:]
p = pressure(claw.frames[frameno])
plt.plot(x,p,'-')
plt.title("time="+str(claw.frames[frameno].t))

# %% [markdown]
# To examine the evolution more thoroughly, it's nice to see all the frames in sequence.  We can do this as follows.

# %%
import numpy as np
import matplotlib
#matplotlib.use("Agg")
import matplotlib.pyplot as plt
import matplotlib.animation as manimation
from matplotlib import animation
import matplotlib.pyplot as plt
from clawpack.visclaw.JSAnimation import IPython_display
import numpy as np


frame = claw.frames[0]
density = frame.q[0,:]
p = pressure(frame)

fig = plt.figure(figsize(4,2))
ax = plt.axes(xlim=(0, xmax), ylim=(0, np.max(p)+10))
line, = ax.plot([], [], lw=2)
plt.title("time="+str(frame.t))


def fplot(frame_number):
    frame = claw.frames[frame_number]
    #density = frame.q[0,:]
    p = pressure(frame)
    t = frame.t
    xlab = x+D*t
    ax.set_xlim([xlab[0], xlab[-1]])
    line.set_data(x+D*t,p)
    ax.set_title('Pressure at t='+str(t))
    return line,

animation.FuncAnimation(fig, fplot, frames=len(claw.frames), interval=50, blit=True)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, frame_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.frame_id = frame_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#     document.getElementById(this.frame_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgaaecaec0ce833c0d" style="width:Nonepx">
#     <br>
#     <input id="_anim_slideraaecaec0ce833c0d" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animaaecaec0ce833c0d.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animaaecaec0ce833c0d.slower()">&#8211;</button>
#     <button onclick="animaaecaec0ce833c0d.first_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animaaecaec0ce833c0d.previous_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animaaecaec0ce833c0d.reverse_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animaaecaec0ce833c0d.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animaaecaec0ce833c0d.play_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animaaecaec0ce833c0d.next_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animaaecaec0ce833c0d.last_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="animaaecaec0ce833c0d.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectaaecaec0ce833c0d" class="anim_control">
#     <input id="_frame_noaaecaec0ce833c0d" type="textbox" size="1" onchange="animaaecaec0ce833c0d.set_frame(parseInt(this.value));" onpaste="this.onchange();" oninput="this.onchange();"></input>
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgaaecaec0ce833c0d";
#     var slider_id = "_anim_slideraaecaec0ce833c0d";
#     var frame_id = "_frame_noaaecaec0ce833c0d"
#     var loop_select_id = "_anim_loop_selectaaecaec0ce833c0d";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAFxxJREFUeJzt3X1UU+cdB/BvQIpgeC+ECGiqNoCIwKrInLQ4BLejWD10\
# KKciTjur3eqqTtHaCVtbwVVbsS/TOmo9c3a6dVNUtButqHUOWkGp9SjqBJEGK/Ii4UUg/PbHLQEk\
# yMUmuQn8Pufk5N6bl/vj2nz7PE9ungtikho5ciQ5ODiQXC4nhUJBCxcuJK1WK3VZZiGTyejatWu9\
# Pr5r1y6aMmXKQ7//mjVryMPDgzw8PCglJeWBz83NzSV/f39ydHSkqVOnUllZ2UPvl4lnAyYpmUyG\
# w4cPo76+HoWFhfjyyy/x2muv9XheW1ubBNV1p9PpjP6eRGT09wSAHTt24ODBgyguLkZxcTEOHTqE\
# HTt2GHxuVVUV4uPj8frrr6OmpgYTJkzA3LlzTVIXu4/UCTjYqVQq+vTTT/Xrv/nNbyguLo6IhBbC\
# u+++S2PGjKFRo0YREdGhQ4coJCSEXF1dafLkyVRcXKx/bUZGBvn4+JCTkxP5+/vr3zc/P5+eeOIJ\
# cnZ2JoVCQStXriQiouPHj5Ovr2+3ekaOHKl/XWpqKsXHx9P8+fPJ2dmZsrKyqLa2lhYtWkRKpZJ8\
# fHzolVdeIZ1OZ/Bvy8/Pp4iICHJ1dSWlUkm/+tWvqKWlhYiIIiMjSSaT0bBhw0gul9P+/fu7vfbi\
# xYs0dOhQsrW1JblcTm5ubv06rj/84Q9p586d+vUPPviAIiIiDD53x44d9KMf/Ui/3tDQQA4ODnT5\
# 8uV+7ZP1HweQxFQqFeXm5hIR0Y0bNygoKIg2bNhAREIAxcbGUk1NDTU3N1NhYSF5eXlRQUEBtbe3\
# 0+7du0mlUlFLSwtdunSJ/Pz8SKPREBFRWVmZvnsTERFBe/bsISLhw5Wfn09EhgOoayCmpqaSnZ0d\
# HTx4kIiImpqaaPbs2bR06VJqbGykb7/9lsLDw2nHjh0G/7azZ89Sfn4+6XQ6Ki0tpcDAQNq6dav+\
# 8b66YB9++GGPLlh6ejq5uroavHUNKRcXFyooKNCvf/nll+Tk5GRwP8uXL6cXXnih27bg4GD6+OOP\
# e62NGQd3wSRGRJg9ezbc3NwQGRmJqKgovPzyy/rH161bB1dXV9jb2+P999/H888/j4kTJ0Imk2HB\
# ggWwt7fHmTNnMGTIENy7dw9ff/01WltbMWLECIwaNQoA8Mgjj+DKlSuoqqqCo6MjwsPDRdc3efJk\
# zJo1CwBQV1eHo0eP4q233oKDgwM8PT3x0ksv4a9//avB1/7gBz9AeHg4bGxsMHLkSCxZsgQnTpzo\
# 17G539q1a1FTU2PwVl1drX+eVquFi4uLft3Z2RlardbgfhoaGuDs7Nxt24Oez4yHA0hiMpkMBw8e\
# RE1NDUpLS/HOO+/A3t5e/7ifn59+uaysDFu2bIGbm5v+dvPmTWg0GowePRpbt25FWloaFAoFEhMT\
# odFoAABZWVkoKSlBYGAgwsPDceTIEdH1+fr6dtt/a2srlEqlfv9Lly7F7du3Db62pKQEM2fOhFKp\
# hIuLC9avX487d+709xA9FLlcjrt37+rX6+rqIJfLRT234/lOTk4mrZFxAFk8mUymXx4xYgTWr1/f\
# 7f/6Wq1WP2CamJiIU6dOoaysDDKZDCkpKQCAMWPGYO/evbh9+zZSUlLwzDPPoKmpCcOGDUNjY6P+\
# /XU6XY8w6bp/Pz8/2Nvb486dO/r919XV4auvvjJY+7JlyzB27FhcvXoVdXV1eP3119He3v5Qf3uH\
# jRs3wsnJyeCtaysmKCgI586d06+fP38e48aNM7ifoKAgnD9/Xr/e0NCAa9euISgoSHSt7OFwAFmR\
# X/ziF9i+fTsKCgpARGhoaMCRI0eg1WpRUlKCzz77DPfu3YO9vT2GDh0KW1tbAMCePXv0weLi4gKZ\
# TAYbGxuo1Wo0NzcjJycHra2teO2113Dv3r1e969UKhEbG4uVK1eivr4e7e3tuHbtGk6ePGnw+Vqt\
# Fk5OTnB0dMSlS5fwxz/+sdvjCoUC165d63V/3t7euHnzJlpbW/XbXn75ZdTX1xu8dW3FLFiwAG++\
# +Sa++eYbVFRU4M0338TChQsN7mfOnDm4cOEC/vGPf6C5uRm/+93vEBoaCrVa3WttzEgkHoMa9O7/\
# FqwrGxubHoO0x44do4kTJ+q/WUpISK

# %%
import numpy as np
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
import matplotlib.animation as manimation

FFMpegWriter = manimation.writers['ffmpeg']
metadata = dict(title='Movie Test', artist='Matplotlib',
        comment='Movie support!')
writer = FFMpegWriter(fps=15, metadata=metadata)

frame = claw.frames[0]
density = frame.q[0,:]
p = pressure(frame)

fig = plt.figure(figsize(4,2))
ax = plt.axes(xlim=(0, xmax), ylim=(0, np.max(p)+10))
line, = ax.plot([], [], lw=2)
plt.title("time="+str(frame.t))

with writer.saving(fig, "pulsating_detonation.mp4", 100):
    for i in range(len(claw.frames)):
        fplot(i)
        writer.grab_frame()
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:1318: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
fplot(1)
# Out:
# (<matplotlib.lines.Line2D at 0x7f637d652510>,)
